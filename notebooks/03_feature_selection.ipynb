# %% [markdown]
# # 3. Feature review
# Features are selected by documented availability at review time, before viewing test labels. Severity must be assessed before this model is used.

# %%
from pathlib import Path
import sys
root = Path.cwd().resolve()
if root.name == 'notebooks': root = root.parent
sys.path.insert(0, str(root))

# %%
from src.util import load_config
from src.data_pipeline import prepare
config = load_config()
parts, _ = prepare(save=False)
print('Numeric:', config['numeric_features'])
print('Categorical:', config['categorical_features'])
print('Excluded:', sorted(set(parts['train'].columns) - set(config['numeric_features'] + config['categorical_features'] + [config['target']])))
# Out:
# Numeric: ['months_as_customer', 'policy_annual_premium', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year']
# Categorical: ['policy_state', 'policy_csl', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'auto_make', 'auto_model']
# Excluded: ['_c39', 'age', 'incident_date', 'incident_location', 'insured_sex', 'insured_zip', 'police_report_available', 'policy_bind_date', 'policy_number', 'total_claim_amount']
