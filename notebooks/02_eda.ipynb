# %% [markdown]
# # 2. Development EDA
# Target associations and plots use the development rows. Structural quality checks use the full CSV.

# %%
from pathlib import Path
import sys
root = Path.cwd().resolve()
if root.name == 'notebooks': root = root.parent
sys.path.insert(0, str(root))

# %%
from src.eda import run
summary = run()
summary['severity']
# Out:
# {
#   "development_rows": 800,
#   "severity": [
#     {
#       "incident_severity": "Trivial Damage",
#       "count": 75,
#       "fraud_rate": 0.08
#     },
#     {
#       "incident_severity": "Minor Damage",
#       "count": 281,
#       "fraud_rate": 0.099644128113879
#     },
#     {
#       "incident_severity": "Total Loss",
#       "count": 225,
#       "fraud_rate": 0.14666666666666667
#     },
#     {
#       "incident_severity": "Major Damage",
#       "count": 219,
#       "fraud_rate": 0.5981735159817352
#     }
#   ]
# }
# [{'incident_severity': 'Trivial Damage', 'count': 75, 'fraud_rate': 0.08},
#  {'incident_severity': 'Minor Damage',
#   'count': 281,
#   'fraud_rate': 0.099644128113879},
#  {'incident_severity': 'Total Loss',
#   'count': 225,
#   'fraud_rate': 0.14666666666666667},
#  {'incident_severity': 'Major Damage',
#   'count': 219,
#   'fraud_rate': 0.5981735159817352}]
